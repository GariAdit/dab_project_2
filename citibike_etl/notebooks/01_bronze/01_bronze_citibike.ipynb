# %%
import dlt
from pyspark.sql.types import StructType, StructField, StringType, DecimalType, TimestampType
from pyspark.sql.functions import create_map, lit

# %%
pipeline_id = dbutils.widgets.get("pipeline_id")
run_id = dbutils.widgets.get("run_id")
task_id = dbutils.widgets.get("task_id")
processed_timestamp = dbutils.widgets.get("processed_timestamp")
catalog = dbutils.widgets.get("catalog")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pipeline_id = dbutils.widgets.get("pipeline_id")
#       2 run_id = dbutils.widgets.get("run_id")
#       3 task_id = dbutils.widgets.get("task_id")
#       4 processed_timestamp = dbutils.widgets.get("processed_timestamp")
#
# File c:\Databricks_CLI_Demo\DAB_PROJECT\.venv_dbc\Lib\site-packages\databricks\sdk\_widgets\__init__.py:10, in WidgetUtils.get(self, name)
#       9 def get(self, name: str):
# ---> 10     return self._get(name)
#
# File c:\Databricks_CLI_Demo\DAB_PROJECT\.venv_dbc\Lib\site-packages\databricks\sdk\_widgets\default_widgets_utils.py:42, in DefaultValueOnlyWidgetUtils._get(self, name)
#      41 def _get(self, name: str) -> str:
# ---> 42     return self._widgets[name]
#
# KeyError: 'pipeline_id'

# %%
schema = StructType([
    StructField("ride_id", StringType(), True),
    StructField("rideable_type", StringType(), True),
    StructField("started_at", TimestampType(), True),
    StructField("ended_at", TimestampType(), True),
    StructField("start_station_name", StringType(), True), 
    StructField("start_station_id", StringType(), True),   
    StructField("end_station_name", StringType(), True), 
    StructField("end_station_id", StringType(), True), 
    StructField("start_lat", DecimalType(), True), 
    StructField("start_lng", DecimalType(), True), 
    StructField("end_lat", DecimalType(), True), 
    StructField("end_lng", DecimalType(), True), 
    StructField("member_casual", StringType(), True), 
])

# %%
df = spark.read.csv(f"/Volumes/{catalog}/00_landing/source_citibike_data/JC-202503-citibike-tripdata.csv", schema=schema, header=True)

# %%
df.show()
# Out:
# +----------------+-------------+--------------------+--------------------+------------------+----------------+--------------------+--------------+---------+---------+-------+-------+-------------+
# |         ride_id|rideable_type|          started_at|            ended_at|start_station_name|start_station_id|    end_station_name|end_station_id|start_lat|start_lng|end_lat|end_lng|member_casual|
# +----------------+-------------+--------------------+--------------------+------------------+----------------+--------------------+--------------+---------+---------+-------+-------+-------------+
# |29DAF43DD84B4B7A|electric_bike|2025-03-20 18:58:...|2025-03-20 19:00:...|   6 St & Grand St|           HB302|Mama Johnson Fiel...|         HB404|       41|      -74|     41|    -74|       member|
# |B11B4220F7195025|electric_bike|2025-03-29 11:01:...|2025-03-29 11:11:...|  Heights Elevator|           JC059|        Jersey & 3rd|         JC074|       41|      -74|     41|    -74|       member|
# |18D5B30305F602B9|electric_bike|2025-03-01 16:05:...|2025-03-01 16:07:...|      Jersey & 3rd|           JC074|       Hamilton Park|         JC009|       41|      -74|     41|    -74|       member|
# |40C1173521E0136C|electric_bike|2025-03-12 21:22:...|2025-03-12 21:30:...|    Jackson Square|           JC063|Bergen Ave & Sip Ave|         JC109|       41|      -74|     41|    -74|       member|
# |BEFCB12738E44387|electric_bike|2025-03-26 14:03:...|2025-03-26 14:10:...|    Jackson Square|           JC063|        Glenwood Ave|         JC094|       41|      -74|     41|    -74|       member|
# +----------------+-------------+--------------------+--------------------+------------------+----------------+--------------------+--------------+---------+---------+-------+-------+-------------+
# only showing top 20 rows

# %%
df = df.withColumn("metadata", 
              create_map(
                  lit("pipeline_id"), lit(pipeline_id),
                  lit("run_id"), lit(run_id),
                  lit("task_id"), lit(task_id),
                  lit("processed_timestamp"), lit(processed_timestamp)
                  ))

# %%
df.show()
# Out:
# +----------------+-------------+--------------------+--------------------+------------------+----------------+--------------------+--------------+---------+---------+-------+-------+-------------+--------------------+
# |         ride_id|rideable_type|          started_at|            ended_at|start_station_name|start_station_id|    end_station_name|end_station_id|start_lat|start_lng|end_lat|end_lng|member_casual|            metadata|
# +----------------+-------------+--------------------+--------------------+------------------+----------------+--------------------+--------------+---------+---------+-------+-------+-------------+--------------------+
# |29DAF43DD84B4B7A|electric_bike|2025-03-20 18:58:...|2025-03-20 19:00:...|   6 St & Grand St|           HB302|Mama Johnson Fiel...|         HB404|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |B11B4220F7195025|electric_bike|2025-03-29 11:01:...|2025-03-29 11:11:...|  Heights Elevator|           JC059|        Jersey & 3rd|         JC074|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |18D5B30305F602B9|electric_bike|2025-03-01 16:05:...|2025-03-01 16:07:...|      Jersey & 3rd|           JC074|       Hamilton Park|         JC009|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |532EB2D9DB68567D|electric_bike|2025-03-21 18:44:...|2025-03-21 18:51:...|      Jersey & 3rd|           JC074|     Jersey & 6th St|         JC027|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |EA7C9C945D7D57AA|electric_bike|2025-03-20 11:08:...|2025-03-20 11:12:...|   6 St & Grand St|           HB302|   Madison St & 1 St|         HB402|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |DA232FF47222E86C| classic_bike|2025-03-13 11:11:...|2025-03-13 11:15:...|   6 St & Grand St|           HB302|   Madison St & 1 St|         HB402|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |416547516DE5132F|electric_bike|2025-03-28 21:51:...|2025-03-28 21:57:...|           Hilltop|           JC019| Leonard Gordon Park|         JC080|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |E25EDA33910F90F0|electric_bike|2025-03-13 18:21:...|2025-03-13 18:26:...|           Hilltop|           JC019| Leonard Gordon Park|         JC080|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |D209FF2521E26D16| classic_bike|2025-03-01 14:59:...|2025-03-01 15:06:...|    Jackson Square|           JC063|          Bergen Ave|         JC095|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |BC9F0D06A5AFF751|electric_bike|2025-03-04 09:55:...|2025-03-04 09:59:...|   6 St & Grand St|           HB302|Southwest Park - ...|         HB401|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |7DD3A6B5272F27F5|electric_bike|2025-03-05 07:46:...|2025-03-05 07:51:...|   6 St & Grand St|           HB302|Southwest Park - ...|         HB401|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |EBC8115E0E51D260|electric_bike|2025-03-22 10:44:...|2025-03-22 10:47:...|   6 St & Grand St|           HB302|Clinton St & Newa...|         HB409|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |8E81A7E630ACC8A3|electric_bike|2025-03-20 18:46:...|2025-03-20 18:52:...|   Christ Hospital|           JC034|    Heights Elevator|         JC059|       41|      -74|     41|    -74|       casual|{pipeline_id -> p...|
# |C3C27AC1CE0191D8|electric_bike|2025-03-28 12:45:...|2025-03-28 12:50:...|           Hilltop|           JC019|     Christ Hospital|         JC034|       41|      -74|     41|    -74|       casual|{pipeline_id -> p...|
# |31A0007D2C09136A|electric_bike|2025-03-03 16:29:...|2025-03-03 16:38:...|    Columbus Drive|           JC014|Baldwin at Montgo...|         JC020|       41|      -74|     41|    -74|       casual|{pipeline_id -> p...|
# |696F0B0FACBB2EB1|electric_bike|2025-03-14 08:04:...|2025-03-14 08:11:...|   Christ Hospital|           JC034|      Journal Square|         JC103|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |2F9A9DFC0B5FDC8B|electric_bike|2025-03-04 08:10:...|2025-03-04 08:17:...|   Christ Hospital|           JC034|      Journal Square|         JC103|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |6CDBFDD599F49010| classic_bike|2025-03-01 15:27:...|2025-03-01 15:41:...|   Christ Hospital|           JC034|      Journal Square|         JC103|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |40C1173521E0136C|electric_bike|2025-03-12 21:22:...|2025-03-12 21:30:...|    Jackson Square|           JC063|Bergen Ave & Sip Ave|         JC109|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# |BEFCB12738E44387|electric_bike|2025-03-26 14:03:...|2025-03-26 14:10:...|    Jackson Square|           JC063|        Glenwood Ave|         JC094|       41|      -74|     41|    -74|       member|{pipeline_id -> p...|
# +----------------+-------------+--------------------+--------------------+------------------+----------------+--------------------+--------------+---------+---------+-------+-------+-------------+--------------------+
# only showing top 20 rows

# %%
df.write.\
    mode("overwrite").\
    option("overwriteSchema", "true").\
    saveAsTable(f"{catalog}.01_bronze.jc_citibike")
